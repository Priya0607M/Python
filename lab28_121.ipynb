# %%
from plotnine.data import mpg
from plotnine import ggplot, aes, geom_point

ggplot(mpg) + aes(x="class", y="hwy") + geom_point()

# %%
from plotnine.data import economics
from plotnine import ggplot, aes, geom_line

(
    ggplot(economics)  # What data to use
    + aes(x="date", y="pop")  # What variable to use
    + geom_line()  # Geometric object to use for drawing
)

# %%
from plotnine.data import economics

print(economics)
# Out:
#           date      pce     pop  psavert  uempmed  unemploy
# 0   1967-07-01    507.4  198712     12.5      4.5      2944
# 1   1967-08-01    510.5  198911     12.5      4.7      2945
# 2   1967-09-01    516.3  199113     11.7      4.6      2958
# 3   1967-10-01    512.9  199311     12.5      4.9      3143
# 4   1967-11-01    518.1  199498     12.5      4.7      3066
# ..         ...      ...     ...      ...      ...       ...
# 569 2014-12-01  12122.0  320201      5.0     12.6      8688
# 570 2015-01-01  12080.8  320367      5.5     13.4      8979
# 571 2015-02-01  12095.9  320534      5.7     13.1      8705
# 572 2015-03-01  12161.5  320707      5.2     12.2      8575
# 573 2015-04-01  12158.9  320887      5.6     11.7      8549
#
# [574 rows x 6 columns]

# %%
pip install plotnine
# Out:
# Requirement already satisfied: plotnine in c:\users\priya\anaconda3\lib\site-packages (0.15.1)
# Requirement already satisfied: matplotlib>=3.8.0 in c:\users\priya\anaconda3\lib\site-packages (from plotnine) (3.10.0)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\priya\anaconda3\lib\site-packages (from plotnine) (2.2.3)
# Requirement already satisfied: mizani~=0.14.0 in c:\users\priya\anaconda3\lib\site-packages (from plotnine) (0.14.3)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\priya\anaconda3\lib\site-packages (from plotnine) (2.3.4)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\priya\anaconda3\lib\site-packages (from plotnine) (1.15.3)
# Requirement already satisfied: statsmodels>=0.14.5 in c:\users\priya\anaconda3\lib\site-packages (from plotnine) (0.14.5)
# Requirement already satisfied: tzdata in c:\users\priya\anaconda3\lib\site-packages (from mizani~=0.14.0->plotnine) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib>=3.8.0->plotnine) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib>=3.8.0->plotnine) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib>=3.8.0->plotnine) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib>=3.8.0->plotnine) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib>=3.8.0->plotnine) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib>=3.8.0->plotnine) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib>=3.8.0->plotnine) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib>=3.8.0->plotnine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\priya\anaconda3\lib\site-packages (from pandas>=2.2.0->plotnine) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\priya\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.8.0->plotnine) (1.17.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\priya\anaconda3\lib\site-packages (from statsmodels>=0.14.5->plotnine) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.
